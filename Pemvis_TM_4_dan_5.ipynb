# %% [markdown]
# <a href="https://colab.research.google.com/github/DJunichiR/Pemrograman-Visual/blob/main/Pemvis_TM_4_dan_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-8,8,10000)
plt.figure(figsize=(8,6.5))

#Tentukan persamaan matematika yang diinginkan
y = x -x -0
y1 = (4-x**2)**0.5
y2 = -(4-x**2)**0.5

y3 = 5 + (4-(x-5)**2)**0.5
y4 = 5 - (4-(x-5)**2)**0.5

y5 = -5 + (4-(x-5)**2)**0.5
y6 = -5 - (4-(x-5)**2)**0.5

y7 = 5 + (4-(x+5)**2)**0.5
y8 = 5 - (4-(x+5)**2)**0.5

y9 = -5 + (4-(x+5)**2)**0.5
y10 = -5 - (4-(x+5)**2)**0.5

plt.plot(x, y, '-k')
plt.plot(x, y1, '-r', label='y1, y2')
plt.plot(x, y2, '-r')
plt.plot(x, y3, '-g', label='y3, y4')
plt.plot(x, y4, '-g')
plt.plot(x, y5, '-b', label='y5, y6')
plt.plot(x, y6, '-b')
plt.plot(x, y7, '-y', label='y7, y8')
plt.plot(x, y8, '-y')
plt.plot(x, y9, '-y', label='y9, y10')
plt.plot(x, y10, '-y')

plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# <ipython-input-4-5e2d5e2e1e27>:10: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (4-x**2)**0.5
# <ipython-input-4-5e2d5e2e1e27>:11: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(4-x**2)**0.5
# <ipython-input-4-5e2d5e2e1e27>:13: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 5 + (4-(x-5)**2)**0.5
# <ipython-input-4-5e2d5e2e1e27>:14: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 5 - (4-(x-5)**2)**0.5
# <ipython-input-4-5e2d5e2e1e27>:16: RuntimeWarning: invalid value encountered in sqrt
#   y5 = -5 + (4-(x-5)**2)**0.5
# <ipython-input-4-5e2d5e2e1e27>:17: RuntimeWarning: invalid value encountered in sqrt
#   y6 = -5 - (4-(x-5)**2)**0.5
# <ipython-input-4-5e2d5e2e1e27>:19: RuntimeWarning: invalid value encountered in sqrt
#   y7 = 5 + (4-(x+5)**2)**0.5
# <ipython-input-4-5e2d5e2e1e27>:20: RuntimeWarning: invalid value encountered in sqrt
#   y8 = 5 - (4-(x+5)**2)**0.5
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-8,7,100000)
plt.figure(figsize=(9,5.5))

#Tentukan persamaan matematika yang diinginkan

y1 = (18-x**2)**0.5
y2 = -(18-x**2)**0.5

y3 = 4 + (4-(x-4.8)**2)**0.5
y4 = 4 - (4-(x-4.8)**2)**0.5

y7 = 4 + (4-(x+4.8)**2)**0.5
y8 = 4 - (4-(x+4.8)**2)**0.5


plt.plot(x, y1, '-k')
plt.plot(x, y2, '-k')
plt.plot(x, y3, '-k')
plt.plot(x, y4, '-k')
plt.plot(x, y7, '-k')
plt.plot(x, y8, '-k')

plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# <ipython-input-30-383124dcf98d>:10: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (18-x**2)**0.5
# <ipython-input-30-383124dcf98d>:11: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(18-x**2)**0.5
# <ipython-input-30-383124dcf98d>:13: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 4 + (4-(x-4.8)**2)**0.5
# <ipython-input-30-383124dcf98d>:14: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 4 - (4-(x-4.8)**2)**0.5
# <ipython-input-30-383124dcf98d>:16: RuntimeWarning: invalid value encountered in sqrt
#   y7 = 4 + (4-(x+4.8)**2)**0.5
# <ipython-input-30-383124dcf98d>:17: RuntimeWarning: invalid value encountered in sqrt
#   y8 = 4 - (4-(x+4.8)**2)**0.5
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-4,4,10000)
plt.figure(figsize=(3,10))


#Gambar lingkarang kecil (titik) pada (0,0)
plt.plot(x, -(0.01-x**2)**0.5, '-k')
plt.plot(x, ((0.01-x**2)**0.5), '-k')

#Tentukan persamaan matematika yang diinginkan
y = x - x - 0
y1 = 2*x**3 - 3*x**2 + 2*x + 5

plt.plot(x, y, '-k')

plt.plot(x, y1, '-r', label='y1')

plt.legend(loc='upper left')
plt.grid()
# Out:
# <ipython-input-38-b04f9c16ea5e>:7: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -(0.01-x**2)**0.5, '-k')
# <ipython-input-38-b04f9c16ea5e>:8: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, ((0.01-x**2)**0.5), '-k')

# %%
import matplotlib.pyplot as plt
import numpy as np

#Tentukan wilayah (domain) diagram Cartesian dan rasio lebar dan tinggi diagram
x = np.linspace(-3,3,10000)
plt.figure(figsize=(3,10))


#Gambar lingkarang kecil (titik) pada (0,0)
plt.plot(x, (0.01-x**2)**0.5, '-k')
plt.plot(x, -((0.01-x**2)**0.5), '-k')

#Tentukan persamaan matematika yang diinginkan
y = x - x - 0
y1 = -(x**3 - 2*x**2 - x +2)

plt.plot(x, y, '-k')

plt.plot(x, y1, '-r', label='y1')

plt.legend(loc='upper left')
plt.grid()
plt.show()
# Out:
# <ipython-input-37-d4fb6877422a>:10: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01-x**2)**0.5, '-k')
# <ipython-input-37-d4fb6877422a>:11: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -((0.01-x**2)**0.5), '-k')

# %%
#PART 1
#Constructing a Set (there are two methods)
Set_1 = {"Toyota", "Daihatsu", "Honda"}
Set_2 = set((("Toyota", "Daihatsu", "Honda")))

print("Tipe data Set_1 adalah", type(Set_1))
print("Tipe data Set_2 adalah", type(Set_2))
print("--------------------------------------------")

#Print every item of Set_1
for x in Set_1:
  print(x)
print("--------------------------------------------")

#Check the length of the set
print(len(Set_1))

#Check if a key exist
if "Daihatsu" in Set_1:
  print("Yes, Daihatsu is an item in Set_1.")

#Add an item
Set_1.add("Mitsubishi")
print(Set_1)

#Add multiple items
Set_1.update(["Suzuki", "Mazda", "Nissan"])
print(Set_1)

#PART 2
#Remove an item (method1)
Set_1.remove("Honda")
print(Set_1)

#Remove an item (method2)
Set_1.discard("Mazda")
print(Set_1)

#Delete (pop) the last inserted key
Set_1.pop()
print(Set_1)

#Clear the set
Set_1.clear()
print(Set_1)

#Delete the  set
del Set_1
print("-----------------------------------------------")

#Union of two sets
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print(set3)
print("------------------------------------------------")
#Set 1 takes copies of all items of set 2
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set1.update(set2)
print(set1)
# Out:
# Tipe data Set_1 adalah <class 'set'>
# Tipe data Set_2 adalah <class 'set'>
# --------------------------------------------
# Toyota
# Honda
# Daihatsu
# --------------------------------------------
# 3
# Yes, Daihatsu is an item in Set_1.
# {'Toyota', 'Mitsubishi', 'Honda', 'Daihatsu'}
# {'Toyota', 'Daihatsu', 'Suzuki', 'Mazda', 'Honda', 'Nissan', 'Mitsubishi'}
# {'Toyota', 'Daihatsu', 'Suzuki', 'Mazda', 'Nissan', 'Mitsubishi'}
# {'Toyota', 'Daihatsu', 'Suzuki', 'Nissan', 'Mitsubishi'}
# {'Daihatsu', 'Suzuki', 'Nissan', 'Mitsubishi'}
# set()
# -----------------------------------------------
# {'a', 1, 2, 'c', 3, 'b'}
# ------------------------------------------------
# {'a', 1, 2, 'c', 3, 'b'}

# %%
# Case 1
print("Case 1")
# Declaring Boolean values (Standard way)
f = bool(True)
g = bool(False)
print(f)
print(g)
print("=============================================================")

# Case 2
print("Case 2")
# Boolean values in different contexts
# Automatically tracked by the computer without declaration
print(3 > 2)
print(3 + 2 == 5)
print(3 < 2)
print("=============================================================")

# Case 3
print("Case 3")
Penghasilan = 20000000
penghasilan_tanpa_pajak = 4000000
if penghasilan_tanpa_pajak >= Penghasilan:
    pajak_yang_harus_dibayar = 0
if Penghasilan > penghasilan_tanpa_pajak:
    pajak_yang_harus_dibayar = 0.1 * Penghasilan

print("Pajak yang harus Anda bayar: Rp ", pajak_yang_harus_dibayar)

print("Case 4")
# Semua data yang tidak nol (kosong) memiliki nilai Boolean True

a = 3
b = "Ini data string."
c = "laptop", "buku", "ballpen"  # tuple
d = ["laptop", "buku", "ballpen"]  # list
e = {"Laptop": "asus", "buku": "buku_teks", "ballpen": "arrow"}  # dictionary
f = {1, 2, 3, 4, 5}  # set
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
print(bool(f))
print("=============================================================")

# PART 3
# Case 5: Variables that are empty have a Boolean value of False
print("Case 5")

a = 0
b = ""
c = ()
d = []
e = {}

print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
print("=============================================================")

# Case 6: Variables with a length of zero have a Boolean value of False
print("Case 6")

class MyClass:
    def _len_(self):
        return 0

print(bool(MyClass()))
print("=============================================================")
# Out:
# Case 1
# True
# False
# ...
# Case 2
# True
# True
# False
# ...
# Case 3
# Pajak yang harus Anda bayar: Rp  2000000.0
# Case 4
# True
# True
# True
# True
# True
# True
# ...
# Case 5
# False
# False
# False
# False
# False
# ...
# Case 6
# True
# ...

# %%
#Latihan Set
# Memasukkan kalimat
kalimat = input("Masukkan kalimat: ")

# Memisahkan kalimat menjadi kata-kata
kata_kata = kalimat.split()

# Mengkonversi list kata-kata menjadi set untuk menghapus duplikat
kata_unik = set(kata_kata)

# Mencetak daftar kata-kata unik
print("Kata-kata unik dalam kalimat:")
for kata in kata_unik:
    print(kata)
# Out:
# Masukkan kalimat: anjas kelas
# Kata-kata unik dalam kalimat:
# anjas
# kelas

# %%
# Input untuk menentukan status cuaca
status_cuaca = input("Apakah cuaca cerah? (Ya/Tidak): ")

# Mengubah input menjadi nilai boolean
if status_cuaca.lower() == "ya":
    sunny = True
elif status_cuaca.lower() == "tidak":
    sunny = False
else:
    print("Masukan tidak valid. Silakan masukkan 'Ya' atau 'Tidak'.")
    exit()

# Mengecek status cuaca dan menampilkan pesan
if sunny:
    print("Hari ini cuaca cerah. Anda mungkin tidak memerlukan payung.")
else:
    print("Hari ini tidak cerah. Siapkan payung jika Anda pergi ke luar.")
# Out:
# Apakah cuaca cerah? (Ya/Tidak): Ya
# Hari ini cuaca cerah. Anda mungkin tidak memerlukan payung.
